# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")

# %%
sequence_to_classify = "one day I will see the world"
candidate_labels = ['positive', 'negative']
classifier(sequence_to_classify, candidate_labels)
#{'labels': ['travel', 'dancing', 'cooking'],
# 'scores': [0.9938651323318481, 0.0032737774308770895, 0.002861034357920289],
# 'sequence': 'one day I will see the world'}
# add result to dataframe
# normalize score to range from -1 to 1
# for every song, get classification in these ranges:
# 1st axis: positive to negative
# 2nd axis: unique to boring
# 3rd axis: formal to informal
# Out:
# {'sequence': 'one day I will see the world',
#  'labels': ['positive', 'negative'],
#  'scores': [0.6139026284217834, 0.38609743118286133]}

# %%
def classify_song(classifier, song, labels):
    candidate_labels = labels
    result = classifier(song, candidate_labels)
    # add and normalize scores
    score = result['scores'][0] - result['scores'][1]
    return score

# %%
import pandas as pd
with open('dataFile/dataFile.txt', 'r') as file:
    lines = file.readlines()
    for index, line in enumerate(lines):
        lines[index] = line.strip()

dict_result = {'positivity': [], 'uniqueness': [], 'formality': []}

for i, line in enumerate(lines):
    result = classifier(line, candidate_labels)
    positivity = classify_song(classifier, line, ['positive', 'negative'])
    uniqueness = classify_song(classifier, line, ['unique', 'boring'])
    formality = classify_song(classifier, line, ['formal', 'informal'])
    dict_result['positivity'].append(positivity)
    dict_result['uniqueness'].append(uniqueness)
    dict_result['formality'].append(formality)
    # save dictionary to csv every 100 songs
    if i % 100 == 0 and i != 0:
        df_result = pd.DataFrame(dict_result)
        df_result.to_csv(f'dataFile/dataFile{i}.csv')
        dict_result = {'positivity': [], 'uniqueness': [], 'formality': []}
    print(f'{i} songs processed')
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:12                                                                                   │
# │                                                                                                  │
# │    9 for i, line in enumerate(lines):                                                            │
# │   10 │   result = classifier(line, candidate_labels)                                             │
# │   11 │   positivity = classify_song(classifier, line, ['positive', 'negative'])                  │
# │ ❱ 12 │   uniqueness = classify_song(classifier, line, ['unique', 'boring'])                      │
# │   13 │   formality = classify_song(classifier, line, ['formal', 'informal'])                     │
# │   14 │   dict_result['positivity'].append(positivity)                                            │
# │   15 │   dict_result['uniqueness'].append(uniqueness)                                            │
# │                                                                                                  │
# │ in classify_song:3                                                                               │
# │                                                                                                  │
# │   1 def classify_song(classifier, song, labels):                                                 │
# │   2 │   candidate_labels = labels                                                                │
# │ ❱ 3 │   result = classifier(song, candidate_labels)                                              │
# │   4 │   # add and normalize scores                                                               │
# │   5 │   score = result['scores'][0] - result['scores'][1]                                        │
# │   6 │   return score                                                                             │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\transformers\pipelines\zero_shot_classificat │
# │ ion.py:205 in __call__                                                                           │
# │                                                                                                  │
# │   202 │   │   else:                                                                              │
# │   203 │   │   │   raise ValueError(f"Unable to understand extra arguments {args}")               │
# │   204 │   │                                                                                      │
# │ ❱ 205 │   │   return super().__call__(sequences, **kwargs)                                       │
# │   206 │                                                                                          │
# │   207 │   def preprocess(self, inputs, candidate_labels=None, hypothesis_template="This exampl   │
# │   208 │   │   sequence_pairs, sequences = self._args_parser(inputs, candidate_labels, hypothes   │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\transformers\pipelines\base.py:1111 in       │
# │ __call__                                                                                         │
# │                                                                                                  │
# │   1108 │   │   elif is_iterable:                                                                 │
# │   1109 │   │   │   return self.iterate(inputs, preprocess_params, forward_params, postprocess_p  │
# │   1110 │   │   elif self.framework == "pt" and isinstance(self, ChunkPipeline):                  │
# │ ❱ 1111 │   │   │   return next(                                                                  │
# │   1112 │   │   │   │   iter(                                                                     │
# │   1113 │   │   │   │   │   self.get_iterator(                                                    │
# │   1114 │   │   │   │   │   │   [inputs], num_workers, batch_size, preprocess_params, forward_pa  │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\transformers\pipelines\pt_utils.py:124 in    │
# │ __next__                                                                                         │
# │                                                                                                  │
# │   121 │   │   │   return self.loader_batch_item()                                                │
# │   122 │   │                                                                                      │
# │   123 │   │   # We're out of items within a batch                                                │
# │ ❱ 124 │   │   item = next(self.iterator)                                                         │
# │   125 │   │   processed = self.infer(item, **self.params)                                        │
# │   126 │   │   # We now have a batch of "inferred things".                                        │
# │   127 │   │   if self.loader_batch_size is not None:                                             │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\transformers\pipelines\pt_utils.py:266 in    │
# │ __next__                                                                                         │
# │                                                                                                  │
# │   263 │   │   │   │   │   return accumulator                                                     │
# │   264 │   │                                                                                      │
# │   265 │   │   while not is_last:                                                                 │
# │ ❱ 266 │   │   │   processed = self.infer(next(self.iterator), **self.params)                     │
# │   267 │   │   │   if self.loader_batch_size is not None:                                         │
# │   268 │   │   │   │   if isinstance(processed, torch.Tensor):                                    │
# │   269 │   │   │   │   │   first_tensor = processed                                               │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\transformers\pipelines\base.py:1025 in       │
# │ forward                                                                                          │
# │                                                                                                  │
# │   1022 │   │   │   │   inference_context = self.get_inference_context()                          │
# │   1023 │   │   │   │   with inference_context():                                                 │
# │   1024 │   │   │   │   │   model_inputs = self._ensure_tensor_on_device(model_inputs, device=se  │
# │ ❱ 1025 │   │   │   │   │   model_outputs = self._forward(model_inputs, **forward_params)         │
# │   1026 │   │   │   │   │   model_outputs = self._ensure_tensor_on_device(model_outputs, device=  │
# │   1027 │   │   │   else:                                                                         │
# │   1028 │   │   │   │   raise ValueError(f"Framework {self.framework} is not supported")          │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\transformers\pipelines\zero_shot_classificat │
# │ ion.py:224 in _forward                                                                           │
# │                                                                                                  │
# │   221 │   │   candidate_label = inputs["candidate_label"]                                        │
# │   222 │   │   sequence = inputs["sequence"]                                                      │
# │   223 │   │   model_inputs = {k: inputs[k] for k in self.tokenizer.model_input_names}            │
# │ ❱ 224 │   │   outputs = self.model(**model_inputs)                                               │
# │   225 │   │                                                                                      │
# │   226 │   │   model_outputs = {                                                                  │
# │   227 │   │   │   "candidate_label": candidate_label,                                            │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\torch\nn\modules\module.py:1501 in           │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\transformers\models\bart\modeling_bart.py:15 │
# │ 28 in forward                                                                                    │
# │                                                                                                  │
# │   1525 │   │   │   │   f"Passing input embeddings is currently not supported for {self.__class_  │
# │   1526 │   │   │   )                                                                             │
# │   1527 │   │                                                                                     │
# │ ❱ 1528 │   │   outputs = self.model(                                                             │
# │   1529 │   │   │   input_ids,                                                                    │
# │   1530 │   │   │   attention_mask=attention_mask,                                                │
# │   1531 │   │   │   decoder_input_ids=decoder_input_ids,                                          │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\torch\nn\modules\module.py:1501 in           │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\transformers\models\bart\modeling_bart.py:12 │
# │ 60 in forward                                                                                    │
# │                                                                                                  │
# │   1257 │   │   │   )                                                                             │
# │   1258 │   │                                                                                     │
# │   1259 │   │   # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_att  │
# │ ❱ 1260 │   │   decoder_outputs = self.decoder(                                                   │
# │   1261 │   │   │   input_ids=decoder_input_ids,                                                  │
# │   1262 │   │   │   attention_mask=decoder_attention_mask,                                        │
# │   1263 │   │   │   encoder_hidden_states=encoder_outputs[0],                                     │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\torch\nn\modules\module.py:1501 in           │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\transformers\models\bart\modeling_bart.py:11 │
# │ 18 in forward                                                                                    │
# │                                                                                                  │
# │   1115 │   │   │   │   │   None,                                                                 │
# │   1116 │   │   │   │   )                                                                         │
# │   1117 │   │   │   else:                                                                         │
# │ ❱ 1118 │   │   │   │   layer_outputs = decoder_layer(                                            │
# │   1119 │   │   │   │   │   hidden_states,                                                        │
# │   1120 │   │   │   │   │   attention_mask=attention_mask,                                        │
# │   1121 │   │   │   │   │   encoder_hidden_states=encoder_hidden_states,                          │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\torch\nn\modules\module.py:1501 in           │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\transformers\models\bart\modeling_bart.py:46 │
# │ 6 in forward                                                                                     │
# │                                                                                                  │
# │    463 │   │   residual = hidden_states                                                          │
# │    464 │   │   hidden_states = self.activation_fn(self.fc1(hidden_states))                       │
# │    465 │   │   hidden_states = nn.functional.dropout(hidden_states, p=self.activation_dropout,   │
# │ ❱  466 │   │   hidden_states = self.fc2(hidden_states)                                           │
# │    467 │   │   hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=se  │
# │    468 │   │   hidden_states = residual + hidden_states                                          │
# │    469 │   │   hidden_states = self.final_layer_norm(hidden_states)                              │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\torch\nn\modules\module.py:1501 in           │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ c:\Users\kunai\anaconda3\envs\gpt\lib\site-packages\torch\nn\modules\linear.py:114 in forward    │
# │                                                                                                  │
# │   111 │   │   │   init.uniform_(self.bias, -bound, bound)                                        │
# │   112 │                                                                                          │
# │   113 │   def forward(self, input: Tensor) -> Tensor:                                            │
# │ ❱ 114 │   │   return F.linear(input, self.weight, self.bias)                                     │
# │   115 │                                                                                          │
# │   116 │   def extra_repr(self) -> str:                                                           │
# │   117 │   │   return 'in_features={}, out_features={}, bias={}'.format(                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
